# %% [markdown]
# <a href="https://colab.research.google.com/github/cermegno/my-computer-vision/blob/main/attendees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Attendee counter

# %% [markdown]
# #### Grab YOLO model

# %%
from ultralytics import YOLO
model = YOLO("./yolov8m.pt")
model.info()

# %% [markdown]
# #### Show image to analyze

# %%
from IPython.display import Image
Image(filename='image.jpg')

# %% [markdown]
# #### Analyze image

# %%
results = model.predict("image.jpg", save=True)
result = results[0]
result

# %% [markdown]
# #### Show analyzed image

# %%
from IPython.display import Image
Image(filename='runs/detect/predict/image.jpg')

# %%
len(result.boxes)

# %% [markdown]
# #### Show prediction details

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")

# %% [markdown]
# #### Count the amount of people in the image

# %%
num_attendees = 0
for box in result.boxes:
  #print(box.cls[0].item())
  if box.cls[0].item() in [0]:
    num_attendees += 1

# %%
from IPython.display import Markdown, display
display(Markdown("# Number of people: " + str(num_attendees)))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <H3>Thanks for joining our session. Enjoy DTW 2024!!</div>
