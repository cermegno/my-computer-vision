# %% [markdown]
# <a href="https://colab.research.google.com/github/cermegno/my-computer-vision/blob/main/yoloe/yoloe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics

# %%
from ultralytics import YOLOE

# %% [markdown]
# ###Prompt-free model

# %%
# Initialize a YOLOE model
model = YOLOE("yoloe-11l-seg-pf.pt")

# Run detection on the given image
results = model.predict("warehouse.png")

# Show results
results[0].show()
# Out:
# image 1/1 /content/warehouse.png: 384x640 1 cargo, 2 ceilings, 2 factory workshops, 1 forklift, 1 kitchen floor, 3 organizations, 2 scaffolds, 1 steering wheel, 2 tow trucks, 1 workshop, 2320.2ms
# Speed: 3.8ms preprocess, 2320.2ms inference, 31.7ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=897x500>

# %% [markdown]
# ###Text/Visual Prompt models

# %%
# Initialize a YOLOE model
model2 = YOLOE("yoloe-11l-seg.pt")

# Set text prompt to detect person and bus. You only need to do this once after you load the model.
model2.set_classes(["person", "ball"])

# Run detection on the given image
results2 = model2.predict("soccer.png")

# Show results
results2[0].show()
# Out:
# image 1/1 /content/soccer.png: 416x640 5 persons, 1 ball, 1767.7ms
# Speed: 3.0ms preprocess, 1767.7ms inference, 9.4ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=938x595>
